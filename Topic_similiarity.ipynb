# %%
import csv
import numpy as np
from py2neo import Graph
import pandas as pd

# %% [markdown]
# ## Connect with the graph database

# %%
host = "bolt://localhost:7687" # replace this with your Sandbox host
password = "abc123@" # replace this with your Sandbox password
username = "neo4j" #  replace this with your Sandbox username
graph = Graph(host,auth=("neo4j", password))

# %% [markdown]
# ## Read and Create User Node in database

# %%
with open('./data/ratings.csv') as f:
    reader = csv.DictReader(f, delimiter=",")
    userids = range(1, max([int(x['userId']) for x in reader]))

# %%
with driver.session() as session:
    numbers = {"nodes": [{'userid': x} for x in userids]}
    create_userid_query = '''
    UNWIND $nodes as node
    CREATE (n:UserID {userid: node.userid})
    '''
    
    result = graph.run(create_userid_query,nodes=numbers)

# %% [markdown]
# ## Read and Create Movies Node in database

# %%
with driver.session() as session:
    with open('./data/movies.csv') as f:
        reader = csv.DictReader(f, delimiter=",")
        movies = {"nodes": [{'movieId': x['movieId'], 'name': x['title']} for x in reader]}
        create_userid_query = '''
        UNWIND $nodes as node
        CREATE (n:MovieId {movieId: node.movieId, name: node.name})
        '''
        result = graph.run(create_userid_query, movies)

# %% [markdown]
# ## Read and Create Genre Node in database

# %%
with driver.session() as session:
    with open('./data/movies.csv') as f:
        reader = csv.DictReader(f, delimiter=",")
        genres = [x['genres'].split('|') for x in reader]
        genres = sum(genres, [])
        genres = list(set(genres))
        print(genres)
        genres = {"nodes": [{'name': x} for x in genres]}
    create_genre_nodes = '''
        UNWIND $nodes as node
        CREATE (n:Genre {name: node.name})
    '''
    result = session.run(create_genre_nodes, genres)
# Out:
# ['Musical', 'Thriller', 'Animation', 'Mystery', 'Action', 'Adventure', 'Documentary', 'Crime', 'Children', 'Western', '(no genres listed)', 'Comedy', 'Drama', 'War', 'Horror', 'Film-Noir', 'Romance', 'Sci-Fi', 'IMAX', 'Fantasy']

# %% [markdown]
# ## Building a relationship between movies and genre nodes

# %%
print('Create the movieid-belongsto->genres relationship')
with driver.session() as session:
    with open('./data/movies.csv') as f:
        reader = csv.DictReader(f, delimiter=",")
        for line in reader:
            movieid = line['movieId']
            genres = line['genres'].split('|')
            movies = {"records": [{'movieId': movieid, 'genres': genres}]}
            create_movie_genre_relationship = '''
                UNWIND $records as record
                    MATCH (a:MovieId) where a.movieId=record.movieId
                    MATCH (b:Genre) where b.name in record.genres
                    CREATE (a)-[:BELONGSTO]->(b)
            '''
            result = graph.run(create_movie_genre_relationship, movies)
# Out:
# Create the movieid-belongsto->genres relationship

# %% [markdown]
# ### Create a edgelist from our knowledge graph for node embeddings

# %%
# %%bash
# git clone git@github.com:snap-stanford/snap.git
# cd snap/examples/node2vec
# make
# Out:
# Cloning into 'snap'...
# make -C ../../snap-core
# make[1]: Entering directory '/home/osama/Desktop/MS-DS/Graph-based-ml/snap/snap-core'
# g++ -c -std=c++98 -Wall -O3 -DNDEBUG -fopenmp Snap.cpp -I../glib-core
# In file included from ../glib-core/base.h:181,
#                  from Snap.h:9,
#                  from Snap.cpp:4:
# ../glib-core/dt.h: In static member function ‘static int TCh::GetHex(const char&)’:
# ../glib-core/dt.h:1076:5: warning: this ‘else’ clause does not guard... [-Wmisleading-indentation]
#  1076 |     else Fail; return 0;}
#       |     ^~~~
# ../glib-core/dt.h:1076:16: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘else’
#  1076 |     else Fail; return 0;}
#       |                ^~~~~~
# ../glib-core/dt.h: In static member function ‘static char TCh::GetHexCh(const int&)’:
# ../glib-core/dt.h:1080:5: warning: this ‘else’ clause does not guard... [-Wmisleading-indentation]
#  1080 |     else Fail; return 0;}
#       |     ^~~~
# ../glib-core/dt.h:1080:16: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘else’
#  1080 |     else Fail; return 0;}
#       |                ^~~~~~
# In file included from ../glib-core/base.h:183,
#                  from Snap.h:9,
#                  from Snap.cpp:4:
# ../glib-core/ds.h: In member function ‘bool TTuple<TVal, NVals>::operator==(const TTuple<TVal, NVals>&) const’:
# ../glib-core/ds.h:290:5: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#   290 |     for (int i=0; i<Len(); i++) if(ValV[i]!=Tup[i]){return false;} return true; }
#       |     ^~~
# ../glib-core/ds.h:290:68: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#   290 |     for (int i=0; i<Len(); i++) if(ValV[i]!=Tup[i]){return false;} return true; }
#       |                                                                    ^~~~~~
# In file included from ../glib-core/base.h:195,
#                  from Snap.h:9,
#                  from Snap.cpp:4:
# ../glib-core/shash.h: In static member function ‘static void TKeyDatFl<TKey, TDat, THashFunc>::LoadDatV(TSIn&, TVec<TDat>&, int)’:
# ../glib-core/shash.h:53:43: warning: unnecessary parentheses in declaration of ‘SIn’ [-Wparentheses]
#    53 |     for (int i = 0; i < LoadN; i++) { TKey(SIn);  DatV.Add(TDat(SIn)); }
#       |                                           ^~~~~
# ../glib-core/shash.h:53:43: note: remove parentheses
#    53 |     for (int i = 0; i < LoadN; i++) { TKey(SIn);  DatV.Add(TDat(SIn)); }
#       |                                           ^~~~~
#       |                                           -   -
# In file included from Snap.cpp:8:
# ../glib-core/linalg.cpp: In static member function ‘static void TNumericalStuff::LUSolve(const TFltVV&, const TIntV&, TFltV&)’:
# ../glib-core/linalg.cpp:985:9: warning: this ‘else’ clause does not guard... [-Wmisleading-indentation]
#   985 |         else if (sum) ii=i;b[i-1]=sum;
#       |         ^~~~
# ../glib-core/linalg.cpp:985:28: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘else’
#   985 |         else if (sum) ii=i;b[i-1]=sum;
#       |                            ^
# In file included from Snap.cpp:24:
# table.cpp: In member function ‘void TTable::GroupByIntColMP(const TStr&, THashMP<TInt, TVec<TInt, int> >&, TBool) const’:
# table.cpp:1239:8: warning: variable ‘PartitionSize’ set but not used [-Wunused-but-set-variable]
#  1239 |   TInt PartitionSize = Partitions[0].GetVal2()-Partitions[0].GetVal1()+1;
#       |        ^~~~~~~~~~~~~
# In file included from Snap.cpp:24:
# table.cpp: In member function ‘void TTable::SelectAtomicConst(const TStr&, const TPrimitive&, TPredComp, TIntV&, PTable&, TBool, TBool)’:
# table.cpp:2891:12: warning: variable ‘PartitionSize’ set but not used [-Wunused-but-set-variable]
#  2891 |       TInt PartitionSize = Partitions[0].GetVal2()-Partitions[0].GetVal1()+1;
#       |            ^~~~~~~~~~~~~
# table.cpp: In member function ‘void TTable::SetFltColToConstMP(TInt, TFlt)’:
# table.cpp:4156:14: warning: variable ‘PartitionSize’ set but not used [-Wunused-but-set-variable]
#  4156 |         TInt PartitionSize = Partitions[0].GetVal2()-Partitions[0].GetVal1()+1;
#       |              ^~~~~~~~~~~~~
# table.cpp: In member function ‘void TTable::UpdateFltFromTableMP(const TStr&, const TStr&, const TTable&, const TStr&, const TStr&, TFlt)’:
# table.cpp:4200:14: warning: variable ‘PartitionSize’ set but not used [-Wunused-but-set-variable]
#  4200 |         TInt PartitionSize = Partitions[0].GetVal2()-Partitions[0].GetVal1()+1;
#       |              ^~~~~~~~~~~~~
# table.cpp: In member function ‘void TTable::ColGenericOpMP(TInt, TInt, TAttrType, TAttrType, TInt, TArithOp)’:
# table.cpp:4713:14: warning: variable ‘PartitionSize’ set but not used [-Wunused-but-set-variable]
#  4713 |         TInt PartitionSize = Partitions[0].GetVal2()-Partitions[0].GetVal1()+1;
#       |              ^~~~~~~~~~~~~
# table.cpp: In member function ‘void TTable::ColGenericOpMP(const TInt&, const TInt&, TAttrType, const TFlt&, TArithOp, TBool)’:
# table.cpp:5035:14: warning: variable ‘PartitionSize’ set but not used [-Wunused-but-set-variable]
#  5035 |         TInt PartitionSize = Partitions[0].GetVal2()-Partitions[0].GetVal1()+1;
#       |              ^~~~~~~~~~~~~
# In file included from Snap.cpp:40:
# casc.cpp: In function ‘void TSnap::CascFindMP(PNGraph, PTable, TStr, TStr, TStr, TStr, TVec<TVec<TInt, int>, int>&)’:
# casc.cpp:202:8: warning: variable ‘SIdx’ set but not used [-Wunused-but-set-variable]
#   202 |   TInt SIdx = P->GetColIdx(C1);
#       |        ^~~~
# casc.cpp:203:8: warning: variable ‘DIdx’ set but not used [-Wunused-but-set-variable]
#   203 |   TInt DIdx = P->GetColIdx(C2);
#       |        ^~~~
# casc.cpp:204:8: warning: variable ‘StIdx’ set but not used [-Wunused-but-set-variable]
#   204 |   TInt StIdx = P->GetColIdx(C3);
#       |        ^~~~~
# casc.cpp:205:8: warning: variable ‘DuIdx’ set but not used [-Wunused-but-set-variable]
#   205 |   TInt DuIdx = P->GetColIdx(C4);
#       |        ^~~~~
# In file included from Snap.cpp:41:
# sim.cpp: In function ‘PNEANet KNNJaccard(PNGraph, int)’:
# sim.cpp:188:7: warning: variable ‘end’ set but not used [-Wunused-but-set-variable]
#   188 |   int end;
#       |       ^~~
# In file included from Snap.h:13,
#                  from Snap.cpp:4:
# gbase.h: In instantiation of ‘void TSnapQueue<TVal>::Push(const TVal&) [with TVal = TInt]’:
# casc.cpp:160:16:   required from here
# gbase.h:213:14: warning: ‘void* memmove(void*, const void*, size_t)’ writing to an object of type ‘class TInt’ with no trivial copy-assignment; use copy-assignment or copy-initialization instead [-Wclass-memaccess]
#   213 |       memmove(ValV.BegI(), ValV.GetI(First), sizeof(TVal)*Len());
#       |       ~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from ../glib-core/base.h:181,
#                  from Snap.h:9,
#                  from Snap.cpp:4:
# ../glib-core/dt.h:1137:7: note: ‘class TInt’ declared here
#  1137 | class TInt{
#       |       ^~~~
# In file included from ../glib-core/base.h:183,
#                  from Snap.h:9,
#                  from Snap.cpp:4:
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TKeyDat<TStr, TStr>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TKeyDat<TStr, TStr>; TSizeTy = int]’
# ../glib-core/xml.h:162:20:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPt<TXmlTok>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TPt<TXmlTok>; TSizeTy = int]’
# ../glib-core/xml.h:292:49:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPair<TFlt, TFlt>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TPair<TFlt, TFlt>; TSizeTy = int]’
# ../glib-core/xmath.h:218:16:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TInt; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TInt; TSizeTy = int]’
# ../glib-core/unicode.h:1702:13:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPt<TCodecBase>; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = TPt<TCodecBase>; TSizeTy = int]’
# ../glib-core/unicode.h:1892:25:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TWCh; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TWCh; TSizeTy = int]’
# ../glib-core/wch.h:75:45:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TStr; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TStr; TSizeTy = int]’
# ../glib-core/url.h:141:34:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPt<TJsonVal>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TPt<TJsonVal>; TSizeTy = int]’
# ../glib-core/json.h:37:43:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# In file included from ../glib-core/base.h:179,
#                  from Snap.h:9,
#                  from Snap.cpp:4:
# ../glib-core/bd.h: In instantiation of ‘void TPt<TRec>::UnRef() const [with TRec = TNEANet]’:
# ../glib-core/bd.h:480:10:   required from ‘TPt<TRec>::~TPt() [with TRec = TNEANet]’
# network.h:2068:54:   required from here
# ../glib-core/bd.h:472:31: warning: deleting object of polymorphic class type ‘TNEANet’ which has non-virtual destructor might cause undefined behavior [-Wdelete-non-virtual-dtor]
#   472 |       if (Addr->CRef.NoRef()){delete Addr;}
#       |                               ^~~~~~~~~~~
# In file included from ../glib-core/base.h:183,
#                  from Snap.h:9,
#                  from Snap.cpp:4:
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TFlt; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TFlt; TSizeTy = int]’
# table.h:245:45:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPair<TStr, TAttrType_>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TPair<TStr, TAttrType_>; TSizeTy = int]’
# table.h:620:12:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TTriple<TStr, TStr, TStr>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TTriple<TStr, TStr, TStr>; TSizeTy = int]’
# table.h:1083:24:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TCnCom; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TCnCom; TSizeTy = int]’
# cncom.h:185:17:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPt<TGStat>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TPt<TGStat>; TSizeTy = int]’
# gstat.h:176:46:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPair<TInt, TInt>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TPair<TInt, TInt>; TSizeTy = int]’
# ghash.h:461:65:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = long unsigned int; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = long unsigned int; TSizeTy = int]’
# ../glib-core/hash.cpp:44:15:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TBool; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TBool; TSizeTy = int]’
# ../glib-core/unicode.cpp:669:17:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TUStr; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = TUStr; TSizeTy = int]’
# ../glib-core/unicodestring.cpp:56:22:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = char*; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = char*; TSizeTy = int]’
# ../glib-core/tm.cpp:922:15:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPt<TBlobBs>; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = TPt<TBlobBs>; TSizeTy = int]’
# ../glib-core/blobbs.cpp:460:15:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPair<TStr, TStr>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TPair<TStr, TStr>; TSizeTy = int]’
# ../glib-core/lx.cpp:670:15:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TVec<TStr, int>; TSizeTy = int]’:
# ../glib-core/ds.h:566:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add() [with TVal = TVec<TStr, int>; TSizeTy = int]’
# ../glib-core/lx.cpp:679:14:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TQuad<TStr, TStr, TStr, TStr>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TQuad<TStr, TStr, TStr, TStr>; TSizeTy = int]’
# ../glib-core/http.cpp:855:32:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPt<THtmlTok>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TPt<THtmlTok>; TSizeTy = int]’
# ../glib-core/html.cpp:803:24:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPt<THtmlDoc>; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = TPt<THtmlDoc>; TSizeTy = int]’
# ../glib-core/html.cpp:1196:15:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPt<TUrl>; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = TPt<TUrl>; TSizeTy = int]’
# ../glib-core/html.cpp:1248:22:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPt<PVec<TStr> >; TSizeTy = int]’:
# ../glib-core/ds.h:522:102:   required from ‘void TVec<TVal, TSizeTy>::Reserve(const TSizeTy&, const TSizeTy&) [with TVal = TPt<PVec<TStr> >; TSizeTy = int]’
# ../glib-core/ss.cpp:5:44:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPt<TXmlDoc>; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = TPt<TXmlDoc>; TSizeTy = int]’
# ../glib-core/xml.cpp:1438:36:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TGnuPlot::TGpSeries; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = TGnuPlot::TGpSeries; TSizeTy = int]’
# ../glib-core/gnuplot.cpp:164:14:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TKeyDat<TFlt, TFlt>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TKeyDat<TFlt, TFlt>; TSizeTy = int]’
# ../glib-core/gnuplot.cpp:189:15:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TTriple<TInt, TInt, TSFlt>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TTriple<TInt, TInt, TSFlt>; TSizeTy = int]’
# ../glib-core/linalg.cpp:61:16:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TKeyDat<TInt, TFlt>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TKeyDat<TInt, TFlt>; TSizeTy = int]’
# ../glib-core/linalg.cpp:73:26:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TVec<TFlt, int>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TVec<TFlt, int>; TSizeTy = int]’
# ../glib-core/linalg.cpp:1683:25:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TVec<TInt, int>; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = TVec<TInt, int>; TSizeTy = int]’
# network.cpp:132:39:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TVec<TVec<TInt, int>, int>; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = TVec<TVec<TInt, int>, int>; TSizeTy = int]’
# network.cpp:1577:25:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = THash<TInt, TVec<TInt, int> >; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = THash<TInt, TVec<TInt, int> >; TSizeTy = int]’
# network.cpp:1583:26:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TVec<TVec<TFlt, int> >; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = TVec<TVec<TFlt, int> >; TSizeTy = int]’
# network.cpp:1595:25:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = THash<TInt, TVec<TFlt, int> >; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = THash<TInt, TVec<TFlt, int> >; TSizeTy = int]’
# network.cpp:1601:26:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TKeyDat<TSecTm, TInt>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TKeyDat<TSecTm, TInt>; TSizeTy = int]’
# timenet.cpp:51:17:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TTimeNet::TTmBucket; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TTimeNet::TTmBucket; TSizeTy = int]’
# timenet.cpp:83:46:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TTriple<TFlt, TFlt, TFlt>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TTriple<TFlt, TFlt, TFlt>; TSizeTy = int]’
# timenet.cpp:129:16:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TTuple<TFlt, 4>; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = TTuple<TFlt, 4>; TSizeTy = int]’
# timenet.cpp:289:17:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TSecTm; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = TSecTm; TSizeTy = int]’
# timenet.cpp:755:16:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TCrossNet; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = TCrossNet; TSizeTy = int]’
# mmnet.cpp:1144:18:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPair<TAttrType_, TInt>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TPair<TAttrType_, TInt>; TSizeTy = int]’
# table.cpp:1753:13:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPt<TTable>; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = TPt<TTable>; TSizeTy = int]’
# table.cpp:1876:15:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPt<TNEANet>; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = TPt<TNEANet>; TSizeTy = int]’
# table.cpp:3622:22:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPair<TNGraphMP::TEdgeI, TNGraphMP::TEdgeI>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TPair<TNGraphMP::TEdgeI, TNGraphMP::TEdgeI>; TSizeTy = int]’
# table.cpp:3818:21:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPair<TFlt, TInt>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TPair<TFlt, TInt>; TSizeTy = int]’
# gsvd.cpp:294:18:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TNEANet::TNodeI; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = TNEANet::TNodeI; TSizeTy = int]’
# centr.cpp:453:11:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TVec<TPair<TFlt, TInt> >; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = TVec<TPair<TFlt, TInt> >; TSizeTy = int]’
# sim.cpp:152:17:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = double; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = double; TSizeTy = int]’
# ggen.cpp:497:13:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPt<TGStatVec>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TPt<TGStatVec>; TSizeTy = int]’
# ff.cpp:375:19:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TSimpleGraph; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = TSimpleGraph; TSizeTy = int]’
# ghash.cpp:291:14:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TPt<TNGraph>; TSizeTy = int]’:
# ../glib-core/ds.h:572:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(TVal&) [with TVal = TPt<TNGraph>; TSizeTy = int]’
# gio.cpp:329:17:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = THashKeyDat<TStr, TInt>; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = THashKeyDat<TStr, TInt>; TSizeTy = int]’
# ../glib-core/hash.h:385:24:   required from ‘int THash<TKey, TDat, THashFunc>::AddKey(const TKey&) [with TKey = TStr; TDat = TInt; THashFunc = TDefaultHashFunc<TStr>]’
# ../glib-core/unicode.h:1740:32:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = char; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = char; TSizeTy = int]’
# ../glib-core/unicode.h:150:124:   required from ‘TStr TUniCodec::EncodeUtf8Str(const TSrcVec&) const [with TSrcVec = TVec<TInt, int>]’
# ../glib-core/unicode.h:1796:73:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = TILxSymSt; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = TILxSymSt; TSizeTy = int]’
# ../glib-core/ds.h:2485:38:   required from ‘void TSStack<TVal>::Push(const TVal&) [with TVal = TILxSymSt]’
# ../glib-core/lx.h:198:58:   required from here
# ../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = THashKeyDat<TStr, TVec<TStr, int> >; TSizeTy = int]’:
# ../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = THashKeyDat<TStr, TVec<TStr, int> >; TSizeTy = int]’
# ../glib-core/hash.h:385:24:   required from ‘int THash<TKey, TDat, THashFunc>::AddKey(const TKey&) [with TKey = TStr; TDat = TVec<TStr, int>; THashFunc = TDefaultHashFunc<TStr>]’
# ../glib-core/url.h:141:61:   required from here
# ...
# ../../glib-core/unicode.h:1223:38:   required from ‘void TUniTrie<TItem_>::Add(const TSrcVec&, size_t, size_t) [with TSrcVec = TVec<TInt, int>; TItem_ = TInt; size_t = long unsigned int]’
# ../../glib-core/unicode.h:1249:36:   required from ‘void TUniTrie<TItem_>::Add(const TSrcVec&) [with TSrcVec = TVec<TInt, int>; TItem_ = TInt]’
# ../../glib-core/unicode.h:1490:72:   required from ‘void TUniChDb::SbEx_Add(const TSrcVec&) [with TSrcVec = TVec<TInt, int>]’
# ../../glib-core/unicode.h:1493:108:   required from here
# ../../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = THashKeyDat<TPair<TInt, TInt>, TVoid>; TSizeTy = int]’:
# ../../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = THashKeyDat<TPair<TInt, TInt>, TVoid>; TSizeTy = int]’
# ../../glib-core/hash.h:385:24:   required from ‘int THash<TKey, TDat, THashFunc>::AddKey(const TKey&) [with TKey = TPair<TInt, TInt>; TDat = TVoid; THashFunc = TDefaultHashFunc<TPair<TInt, TInt> >]’
# ../../glib-core/unicode.h:1224:36:   required from ‘void TUniTrie<TItem_>::Add(const TSrcVec&, size_t, size_t) [with TSrcVec = TVec<TInt, int>; TItem_ = TInt; size_t = long unsigned int]’
# ../../glib-core/unicode.h:1249:36:   required from ‘void TUniTrie<TItem_>::Add(const TSrcVec&) [with TSrcVec = TVec<TInt, int>; TItem_ = TInt]’
# ../../glib-core/unicode.h:1490:72:   required from ‘void TUniChDb::SbEx_Add(const TSrcVec&) [with TSrcVec = TVec<TInt, int>]’
# ../../glib-core/unicode.h:1493:108:   required from here
# ../../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = THashKeyDat<TInt, TUNGraph::TNode>; TSizeTy = int]’:
# ../../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = THashKeyDat<TInt, TUNGraph::TNode>; TSizeTy = int]’
# ../../glib-core/hash.h:385:24:   required from ‘int THash<TKey, TDat, THashFunc>::AddKey(const TKey&) [with TKey = TInt; TDat = TUNGraph::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:240:20:   required from ‘TDat& THash<TKey, TDat, THashFunc>::AddDat(const TKey&, const TDat&) [with TKey = TInt; TDat = TUNGraph::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:561:18:   required from ‘void THash<TKey, TDat, THashFunc>::Defrag() [with TKey = TInt; TDat = TUNGraph::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:457:54:   required from ‘int THash<TKey, TDat, THashFunc>::GetRndKeyId(TRnd&, const double&) [with TKey = TInt; TDat = TUNGraph::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../snap-core/graph.h:226:77:   required from here
# ../../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = THashKeyDat<TInt, TNGraph::TNode>; TSizeTy = int]’:
# ../../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = THashKeyDat<TInt, TNGraph::TNode>; TSizeTy = int]’
# ../../glib-core/hash.h:385:24:   required from ‘int THash<TKey, TDat, THashFunc>::AddKey(const TKey&) [with TKey = TInt; TDat = TNGraph::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:240:20:   required from ‘TDat& THash<TKey, TDat, THashFunc>::AddDat(const TKey&, const TDat&) [with TKey = TInt; TDat = TNGraph::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:561:18:   required from ‘void THash<TKey, TDat, THashFunc>::Defrag() [with TKey = TInt; TDat = TNGraph::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:457:54:   required from ‘int THash<TKey, TDat, THashFunc>::GetRndKeyId(TRnd&, const double&) [with TKey = TInt; TDat = TNGraph::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../snap-core/graph.h:459:77:   required from here
# ../../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = THashKeyDat<TInt, TNEGraph::TNode>; TSizeTy = int]’:
# ../../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = THashKeyDat<TInt, TNEGraph::TNode>; TSizeTy = int]’
# ../../glib-core/hash.h:385:24:   required from ‘int THash<TKey, TDat, THashFunc>::AddKey(const TKey&) [with TKey = TInt; TDat = TNEGraph::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:240:20:   required from ‘TDat& THash<TKey, TDat, THashFunc>::AddDat(const TKey&, const TDat&) [with TKey = TInt; TDat = TNEGraph::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:561:18:   required from ‘void THash<TKey, TDat, THashFunc>::Defrag() [with TKey = TInt; TDat = TNEGraph::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:457:54:   required from ‘int THash<TKey, TDat, THashFunc>::GetRndKeyId(TRnd&, const double&) [with TKey = TInt; TDat = TNEGraph::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../snap-core/graph.h:693:77:   required from here
# ../../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = THashKeyDat<TInt, TNEGraph::TEdge>; TSizeTy = int]’:
# ../../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = THashKeyDat<TInt, TNEGraph::TEdge>; TSizeTy = int]’
# ../../glib-core/hash.h:385:24:   required from ‘int THash<TKey, TDat, THashFunc>::AddKey(const TKey&) [with TKey = TInt; TDat = TNEGraph::TEdge; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:240:20:   required from ‘TDat& THash<TKey, TDat, THashFunc>::AddDat(const TKey&, const TDat&) [with TKey = TInt; TDat = TNEGraph::TEdge; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:561:18:   required from ‘void THash<TKey, TDat, THashFunc>::Defrag() [with TKey = TInt; TDat = TNEGraph::TEdge; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:457:54:   required from ‘int THash<TKey, TDat, THashFunc>::GetRndKeyId(TRnd&, const double&) [with TKey = TInt; TDat = TNEGraph::TEdge; THashFunc = TDefaultHashFunc<TInt>]’
# ../../snap-core/graph.h:697:77:   required from here
# ../../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = THashKeyDat<TInt, TNEANet::TNode>; TSizeTy = int]’:
# ../../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = THashKeyDat<TInt, TNEANet::TNode>; TSizeTy = int]’
# ../../glib-core/hash.h:385:24:   required from ‘int THash<TKey, TDat, THashFunc>::AddKey(const TKey&) [with TKey = TInt; TDat = TNEANet::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:240:20:   required from ‘TDat& THash<TKey, TDat, THashFunc>::AddDat(const TKey&, const TDat&) [with TKey = TInt; TDat = TNEANet::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:561:18:   required from ‘void THash<TKey, TDat, THashFunc>::Defrag() [with TKey = TInt; TDat = TNEANet::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:457:54:   required from ‘int THash<TKey, TDat, THashFunc>::GetRndKeyId(TRnd&, const double&) [with TKey = TInt; TDat = TNEANet::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../snap-core/network.h:2638:77:   required from here
# ../../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = THashKeyDat<TInt, TNEANet::TEdge>; TSizeTy = int]’:
# ../../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = THashKeyDat<TInt, TNEANet::TEdge>; TSizeTy = int]’
# ../../glib-core/hash.h:385:24:   required from ‘int THash<TKey, TDat, THashFunc>::AddKey(const TKey&) [with TKey = TInt; TDat = TNEANet::TEdge; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:240:20:   required from ‘TDat& THash<TKey, TDat, THashFunc>::AddDat(const TKey&, const TDat&) [with TKey = TInt; TDat = TNEANet::TEdge; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:561:18:   required from ‘void THash<TKey, TDat, THashFunc>::Defrag() [with TKey = TInt; TDat = TNEANet::TEdge; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:457:54:   required from ‘int THash<TKey, TDat, THashFunc>::GetRndKeyId(TRnd&, const double&) [with TKey = TInt; TDat = TNEANet::TEdge; THashFunc = TDefaultHashFunc<TInt>]’
# ../../snap-core/network.h:2642:77:   required from here
# ../../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = THashKeyDat<TInt, TUndirNet::TNode>; TSizeTy = int]’:
# ../../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = THashKeyDat<TInt, TUndirNet::TNode>; TSizeTy = int]’
# ../../glib-core/hash.h:385:24:   required from ‘int THash<TKey, TDat, THashFunc>::AddKey(const TKey&) [with TKey = TInt; TDat = TUndirNet::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:240:20:   required from ‘TDat& THash<TKey, TDat, THashFunc>::AddDat(const TKey&, const TDat&) [with TKey = TInt; TDat = TUndirNet::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:561:18:   required from ‘void THash<TKey, TDat, THashFunc>::Defrag() [with TKey = TInt; TDat = TUndirNet::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:457:54:   required from ‘int THash<TKey, TDat, THashFunc>::GetRndKeyId(TRnd&, const double&) [with TKey = TInt; TDat = TUndirNet::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../snap-core/network.h:3394:77:   required from here
# ../../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = THashKeyDat<TInt, TDirNet::TNode>; TSizeTy = int]’:
# ../../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = THashKeyDat<TInt, TDirNet::TNode>; TSizeTy = int]’
# ../../glib-core/hash.h:385:24:   required from ‘int THash<TKey, TDat, THashFunc>::AddKey(const TKey&) [with TKey = TInt; TDat = TDirNet::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:240:20:   required from ‘TDat& THash<TKey, TDat, THashFunc>::AddDat(const TKey&, const TDat&) [with TKey = TInt; TDat = TDirNet::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:561:18:   required from ‘void THash<TKey, TDat, THashFunc>::Defrag() [with TKey = TInt; TDat = TDirNet::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../glib-core/hash.h:457:54:   required from ‘int THash<TKey, TDat, THashFunc>::GetRndKeyId(TRnd&, const double&) [with TKey = TInt; TDat = TDirNet::TNode; THashFunc = TDefaultHashFunc<TInt>]’
# ../../snap-core/network.h:3866:77:   required from here
# ../../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h: In instantiation of ‘void TVec<TVal, TSizeTy>::Resize(const TSizeTy&) [with TVal = THashKeyDat<TTriple<TInt, TInt, TInt>, TInt>; TSizeTy = int]’:
# ../../glib-core/ds.h:570:23:   required from ‘TSizeTy TVec<TVal, TSizeTy>::Add(const TVal&) [with TVal = THashKeyDat<TTriple<TInt, TInt, TInt>, TInt>; TSizeTy = int]’
# ../../glib-core/hash.h:385:24:   required from ‘int THash<TKey, TDat, THashFunc>::AddKey(const TKey&) [with TKey = TTriple<TInt, TInt, TInt>; TDat = TInt; THashFunc = TDefaultHashFunc<TTriple<TInt, TInt, TInt> >]’
# ../../glib-core/hash.h:240:20:   required from ‘TDat& THash<TKey, TDat, THashFunc>::AddDat(const TKey&, const TDat&) [with TKey = TTriple<TInt, TInt, TInt>; TDat = TInt; THashFunc = TDefaultHashFunc<TTriple<TInt, TInt, TInt> >]’
# ../../glib-core/unicode.h:1229:78:   required from ‘void TUniTrie<TItem_>::Add(const TSrcVec&, size_t, size_t) [with TSrcVec = TVec<TInt, int>; TItem_ = TInt; size_t = long unsigned int]’
# ../../glib-core/unicode.h:1249:36:   required from ‘void TUniTrie<TItem_>::Add(const TSrcVec&) [with TSrcVec = TVec<TInt, int>; TItem_ = TInt]’
# ../../glib-core/unicode.h:1490:72:   required from ‘void TUniChDb::SbEx_Add(const TSrcVec&) [with TSrcVec = TVec<TInt, int>]’
# ../../glib-core/unicode.h:1493:108:   required from here
# ../../glib-core/ds.h:799:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   799 |     catch (std::exception Ex){
#       |                           ^~
# ../../glib-core/ds.h:807:27: warning: catching polymorphic type ‘class std::exception’ by value [-Wcatch-value=]
#   807 |     catch (std::exception Ex){
#       |                           ^~
# cp node2vec ../Release

# %%
print('Create the edge list')
with driver.session() as session, open("graph/movies.edgelist", "w") as edges_file:
    result = session.run("""\
    MATCH (m:MovieId)--(other)
    RETURN id(m) AS source, id(other) AS target
    """)

    writer = csv.writer(edges_file, delimiter=" ")

    for row in result:
        writer.writerow([row["source"], row["target"]])
# Out:
# Create the edge list

# %%
# %%bash
# ./snap/examples/node2vec/node2vec -i:./graph/movies.edgelist -o:./emb/movies.emb -l:80 -d:100 -p:0.3 -dr -v
# Out:
# An algorithmic framework for representational learning on graphs. [Nov 30 2022]
# ================================================================================
# Input graph path (-i:)=./graph/movies.edgelist
# Output graph path (-o:)=./emb/movies.emb
# Number of dimensions. Default is 128 (-d:)=100
# Length of walk per source. Default is 80 (-l:)=80
# Number of walks per source. Default is 10 (-r:)=10
# Context size for optimization. Default is 10 (-k:)=10
# Number of epochs in SGD. Default is 1 (-e:)=1
# Return hyperparameter. Default is 1 (-p:)=0.3
# Inout hyperparameter. Default is 1 (-q:)=1
# Verbose output. (-v)=YES
# Graph is directed. (-dr)=YES
# Graph is weighted. (-w)=NO
# Output random walks instead of embeddings. (-ow)=NO
# Read 22084 lines from ./graph/movies.edgelist
# Preprocessing progress: 67.61%
# Walking Progress: 92.19%
# Learning Progress: 99.88%

# %%
with open("emb/movies.emb", "r") as movies_file, driver.session() as session:
    next(movies_file)
    reader = csv.reader(movies_file, delimiter=" ")

    params = []
    for row in reader:
        movie_id = row[0]
        params.append({
            "id": int(movie_id),
            "embedding": [float(item) for item in row[1:]]
        })

    session.run("""\
    UNWIND $params AS param
    MATCH (m:MovieId) WHERE id(m) = param.id
    SET m.embedding = param.embedding
    """, {"params": params})

# %% [markdown]
# ### Build movie simliarity model using node embeddings

# %%
movies_genres_query = """\
MATCH (genre:Genre)
WITH genre ORDER BY genre.name
WITH collect(id(genre)) AS genres
MATCH (m:MovieId)-[:BELONGSTO]->(genre)
WITH genres, id(m) AS source, m.embedding AS embedding, collect(id(genre)) AS target
RETURN source, embedding, [g in genres | CASE WHEN g in target THEN 1 ELSE 0 END] AS genres
"""

with driver.session() as session:
    result = session.run(movies_genres_query)
    df = pd.DataFrame([dict(row) for row in result])

# %%
from gensim.models import KeyedVectors

# %%
filename = 'emb/movies.emb'

# %%
model = KeyedVectors.load_word2vec_format(filename, binary=False)

# %%
def neo4j_most_similar(model, key):
    with driver.session() as session:
        find_movie_query = "MATCH (m:MovieId {name: '%s'}) return id(m)" % key
        result = session.run(find_movie_query)
        for r in result:
            similar_movies = model.most_similar(str(r.value()))
            for s_movie in similar_movies:
                find_movie_query = "MATCH (m:MovieId) where id(m) = %s return m.name" % s_movie[0]
                similar_movie_names = session.run(find_movie_query)
                for sm in similar_movie_names:
                    print(sm.value(), s_movie[1])

# %%
neo4j_most_similar(model, 'Money Train (1995)')
# Out:
# Love Affair (1939) 0.9976007342338562
# Florence Foster Jenkins (2016) 0.9974488615989685
# Fever Pitch (2005) 0.9974387884140015
# Replacement Killers, The (1998) 0.9974029064178467
# Clerks (1994) 0.9973879456520081
# Step Brothers (2008) 0.9973440766334534
# Action Jackson (1988) 0.997317910194397
# Before the Devil Knows You're Dead (2007) 0.9972738027572632
# Twin Dragons (Shuang long hui) (1992) 0.9971912503242493
# Massu Engira Maasilamani (2015) 0.9971174597740173
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [103], in <module>
# ----> 1 neo4j_most_similar(model, 'Money Train (1995)')
#
# Input In [102], in neo4j_most_similar(model, key)
#       4 result = session.run(find_movie_query)
#       5 for r in result:
# ----> 6     similar_movies = model.most_similar(str(r.value()))
#       7     for s_movie in similar_movies:
#       8         find_movie_query = "MATCH (m:MovieId) where id(m) = %s return m.name" % s_movie[0]
#
# File ~/anaconda3/envs/convo-ds-api-env/lib/python3.9/site-packages/gensim/models/keyedvectors.py:842, in KeyedVectors.most_similar(self, positive, negative, topn, clip_start, clip_end, restrict_vocab, indexer)
#     839         weight[idx] = item[1]
#     841 # compute the weighted average of all keys
# --> 842 mean = self.get_mean_vector(keys, weight, pre_normalize=True, post_normalize=True, ignore_missing=False)
#     843 all_keys = [
#     844     self.get_index(key) for key in keys if isinstance(key, _KEY_TYPES) and self.has_index_for(key)
#     845 ]
#     847 if indexer is not None and isinstance(topn, int):
#
# File ~/anaconda3/envs/convo-ds-api-env/lib/python3.9/site-packages/gensim/models/keyedvectors.py:519, in KeyedVectors.get_mean_vector(self, keys, weights, pre_normalize, post_normalize, ignore_missing)
#     517         total_weight += abs(weights[idx])
#     518     elif not ignore_missing:
# --> 519         raise KeyError(f"Key '{key}' not present in vocabulary")
#     521 if(total_weight > 0):
#     522     mean = mean / total_weight
#
# KeyError: "Key '10392' not present in vocabulary"
